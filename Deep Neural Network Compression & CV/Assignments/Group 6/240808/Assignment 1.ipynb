# %% [markdown]
# # Assignment 1

# %% [markdown]
# ## A bit of info before you start.
#
#
# > ***First and foremost, dont use AI to code. Use it to understand and then write code yourself. Use AI to verify if the code you wrote it correct, that will help you learn far far more.***
#
# > ***Implement Stuff from sratch. Use cv2 functions only when numpy implementation can be extremely tedious.***
#
#
#
# You will need to use your own image for this assignment, which you need to import into here.
# If you cant fetch your image from any APIs that dont need credentials, then :
# To preserve an image in Google Colab without a continuous runtime or using Google Drive, you can use base64 string encoding of images ( its really simple )
#
# First, begin by normally uploading the image into the contents folders as you normally do in colab or fetch it using Drive or any API.
#
# To get the base64 string :
# ```
# import base64
# with open("your_image.jpg", "rb") as img_file:
#     print(base64.b64encode(img_file.read()).decode())
# ```
#
# Note that the base64 string is a very long string, click on the three dot icon to the left of the current code cell and click on <code> Copy Cell Output </code> to easily copy it to your clipboard.
#
# Then, to embed the string into your Jupyter Notebook :
# ```
# from PIL import Image
# import io
# import base64
# import matplotlib.pyplot as plt
# import numpy as np
#
# # PASTE BASE64 STRING HERE
# base64_image = "iVBORw0K..."  # long base64 string
#
# img_data = base64.b64decode(base64_image)
# img = Image.open(io.BytesIO(img_data))
#
# plt.imshow(img)
# plt.axis("off")
# ```
# The string is really long so, use a multiline string in python ( syntax : """ """ )
#
# Otherwise, you can also choose to use any API ( try researching on https://picsum.photos/ )

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-540c7144-7c6d-428d-89e5-ec2d3c2259b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-540c7144-7c6d-428d-89e5-ec2d3c2259b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import base64
with open("WhatsApp Image 2025-06-26 at 18.45.11_95fec5a8.jpg", "rb") as img_file:
    print(base64.b64encode(img_file.read()).decode())
# Out:
# ...

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image = """...
"""  # long base64 string

img_data = base64.b64decode(base64_image)
img = Image.open(io.BytesIO(img_data))

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %% [markdown]
# ## Part A
#
# ### Load your image
#
# 1. Display it in RGB
#
# 2. Convert to grayscale ( use NumPy to calculate aggregates using the weighted sum formula )
#
# 3. Use the cvtColor function to do the same and compare results
#
# 3. Print the array shapes of both the RGB and grayscale images
#
# 4. Print a few pixel values of both
#
# ( Do you notice the difference that number of channels created on the array shape ?? )

# %%
# Your PART A codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# ensuring img is in RGB mode
img_rgb=img.convert("RGB")
#convert img into array of shape (H,W,3)
img_array=np.array(img_rgb)
#seperating into channels
r=img_array[:,:,0]
g=img_array[:,:,1]
b=img_array[:,:,2]
#apply weighted formula of grayscale
gray_scale1= 0.299 * r + 0.587 * g + 0.114 * b
# convert pixel values to integer between 0-255
#gray_scale1=gray_scale1.astype(np.uint8)
#numpy can works on float values
# using cvt color function
gray_scale2=cv2.cvtColor(img_array, cv2.COLOR_RGB2GRAY) # cv2 automaticaly converts pixels values to integers

# print array shapes
print("img_rgb shape:",img_array.shape)
print("gray_scale(numpy) shape:",gray_scale1.shape)
print("gray_scale(cv2) shape:",gray_scale2.shape)

# print pixels
print("img_rgb pixel:",img_array[100,100])
print("gray_scale(numpy) pixel:",gray_scale1[100,100])
print("gray_scale(cv2) pixel:",gray_scale2[100,100])






# display img
plt.imshow(img_rgb)
plt.title("RGB image")
plt.axis("off") #  don't want to show x-y axis
plt.show()
# display grayscale(numpy)
plt.imshow(gray_scale1,cmap="gray") # gray is colour map
plt.title("Grayscale(using Numpy)")
plt.axis("off")
plt.show()
# display grayscale(cv2)
plt.imshow(gray_scale2,cmap="gray")
plt.title("Grayscale(using cvtColor)")
plt.axis("off")
plt.show()
# Out:
# img_rgb shape: (1280, 960, 3)
# gray_scale(numpy) shape: (1280, 960)
# gray_scale(cv2) shape: (1280, 960)
# img_rgb pixel: [254 254 254]
# gray_scale(numpy) pixel: 253.99999999999997
# gray_scale(cv2) pixel: 254

# %% [markdown]
# ## Part B
# ### B1. Compute the FFT of the grayscale image ( use NumPy )
# Steps:
# 1. <code>np.fft.fft2</code>
# 2. <code>np.fft.fftshift</code>
# 3. Store as <code>fshift</code>
#
# ### B2. Compute magnitude, phase and display Magnitude Spectrum

# %%
# Your PART B codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# using gray_scale(from cv2) a 2D array signal
gray_scale2=gray_scale2.astype(np.float32)    # convert integer pixel values to float
fft=np.fft.fft2(gray_scale2)  #  2D  complex array output with frequency components
# shifting low frequencies at centre and high frequencies near the edges
fshift=np.fft.fftshift(fft)
# magnitude
magnitude=np.abs(fshift)
# phase
phase=np.angle(fshift)

# converting magnitude into decibals
magnitude_db=20*np.log10(magnitude)

print("gray_scale2:",gray_scale2[100,100])
print("fshift:",fshift[100,100])
print("magnitude:",magnitude_db[100,100])
print("phase:",phase[100,100])

#display

plt.imshow(magnitude_db,cmap="gray")
plt.title("Magnitude Spectrum")
plt.axis("off")
plt.show()

plt.imshow(phase,cmap="gray")
plt.title("Phase Spectrum")
plt.axis("off")
plt.show()
# Out:
# gray_scale2: 254.0
# fshift: (-889.0784-654.1083j)
# magnitude: 60.857613
# phase: -2.507297

# %% [markdown]
# ## Part C
# ### C1. Create 3 LPF masks
#
# Radii of filter: 10, 30, 80 (or image-size dependent, mention if you change)
#
# For each:
#
# 1. Create a mask
#
# 2. Apply to <code>fshift</code>
#
# 3. Reconstruct using <code>ifftshift + ifft2</code>
#
# 4. Show blur levels increasing as radius decreases ( think why and write reason in code comment )
#
# ### C2. Create HPF mask
#
# 1. Apply
#
# 2. Reconstruct
#
# ### C3. Create a square LPF mask
# Keep side of square as 50. The square will be at the center of the filter.
# Apply, Recontruct and show the output.

# %%
# Your PART C codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# size of image
rows,cols=gray_scale2.shape       #(rows,cols)
crow=rows//2      # row number of centred position of array
ccol=cols//2      # col number of centred position of array
# define function for LPF
plt.figure(figsize=(12,5))
plt.subplot(1,4,1)
plt.imshow(gray_scale2,cmap="gray")
plt.title("Original Image")
plt.axis("off")

def lpf(shape, radius):
    rows,cols=shape             # size of LPF
    crow=rows//2                # row number of centred position of LPF
    ccol=cols//2                # col number of centred position of LPF
    # setting each entry of unsigned 8 bit integer =0 in mask
    mask=np.zeros((rows,cols), dtype=np.uint8)
    #  creating a grid of cordinates
    y,x=np.ogrid[:rows, :cols]
    # calculate distance square of each pixel position from centred position
    distance_square=(x-ccol)**2 + (y-crow)**2
    # check points are inside a circle of radius centred at (crow,ccol)
    mask[distance_square <= radius**2] = 1  #set low frequencies position 1
    return mask
radii=[10,30,80]
   # filtered_images=[]   # empty list
for r in radii:
        mask=lpf(gray_scale2.shape,r)
        # setting frequencies out of circle of radius r to 0
        filtered_fshift=fshift*mask
        # getting back to image domain
        filtered_fshift_ishift=np.fft.ifftshift(filtered_fshift) # inverse shift
        filtered_image_complex=np.fft.ifft2(filtered_fshift_ishift)  # inverse fourier tranform to get complex image 2d array
        filtered_image=np.abs(filtered_image_complex) # interest in real part of pixels
      #  filtered_images.insert(filtered_image) # inserting in list
      # display images
        plt.subplot(1,4,radii.index(r)+2)
        plt.imshow(filtered_image,cmap="gray")
        plt.title("radius:"+str(r))
        plt.axis("off")



plt.show()
# as radius decreses very few low frequencies will stay in circle of particular radius or circle shrinks helps in removing edges make image more blur
# as radius become circle expands due to which high frequencies comes in the circle which makes the image less blur

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# High pass Filter
plt.figure(figsize=(12,5))
plt.subplot(1,4,1)
plt.imshow(gray_scale2,cmap="gray")
plt.title("Original Image")
plt.axis("off")
def hpf(shape,radius):
    mask=1-lpf(shape,radius)
    return mask
radii=[10,30,80]
for r in radii:
  mask=hpf(gray_scale2.shape,r)
  filtered_fshift=fshift*mask
  filtered_fshift_ishift=np.fft.ifftshift(filtered_fshift)
  filtered_image_complex=np.fft.ifft2(filtered_fshift_ishift)
  filtered_image=np.abs(filtered_image_complex)
  plt.subplot(1,4,radii.index(r)+2)
  plt.imshow(filtered_image,cmap="gray")
  plt.title("radius:"+str(r))
  plt.axis("off")





plt.show()
# high pass filter allows to keep high frequencies making low frequencies position 0 in fshift upto to a circle of particular radius
# low radius make a tiny spot at the centre where value is 0 and outside more high frequencies keep image more edged
# as radius increses ,spot at centre expands, it removes   larger low frequnecies keeping only very high frequencies making image more dark with thin edges

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

rows,cols=gray_scale2.shape
crow,ccol=rows//2,cols//2

def square_lpf(shape,side):
   rows,cols =shape
   crow,ccol=rows//2,cols//2
   mask=np.zeros((rows,cols),dtype=np.uint8)
   y,x=np.ogrid[:rows, :cols]
   mask[(y>=crow-side//2)&(y<=crow+side//2)&(x>=ccol-side//2)&(x<=ccol+side//2)]=1
   return mask

 # creating square low pass filter of side 50 of same size as grayscale image
mask=square_lpf(gray_scale2.shape,50) # side =50
#setting high frequencies out of square to 0
filtered_fshift=fshift*mask
#taking inverse shift for reconstruct
filtered_fshift_ishift=np.fft.ifftshift(filtered_fshift)
# taking inverse to get back in image domain (complex)
filtered_image_complex=np.fft.ifft2(filtered_fshift_ishift)  # 2d compex array
# taking only real values
filtered_image=np.abs(filtered_image_complex)


# display images
plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
plt.imshow(gray_scale2,cmap="gray")
plt.title("original image")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(filtered_image,cmap="gray")
plt.title("filtered image")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(filtered_fshift.astype(np.uint8),cmap="gray")
plt.title("filtered_fshift")
plt.axis("off")

plt.show()
# Out:
# /tmp/ipython-input-4062516978.py:41: ComplexWarning: Casting complex values to real discards the imaginary part
#   plt.imshow(filtered_fshift.astype(np.uint8),cmap="gray")

# %% [markdown]
# ## Part D
#
# ###D1. Phase-only reconstruction
#
# Use: <code>phase_only = fshift / np.abs(fshift)</code>
#
# 1. Reconstruct and display.
# 2. Also in code comments, mention the differnce between this code line and the one in the lecture : <code>np.angle(f_shift)</code>
# 3. Try recontruction from <code>np.angle(f_shift)</code> once and explain your output in code comments.
#
#
#
# ###D2. Magnitude-only reconstruction
#
# Use: <code>mag_only = np.abs(fshift)</code>
#
# 1. Reconstruct and display.
# 2. Take a guess for the role of logarithm in Magnitude Spectrum. Why does this look different than what Magnitude Spectrum looked like ? Mention in code comments again.

# %%
# Your PART D codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# magnitude and phase of frequency components
#fshift[m,n]= magnitude*e^j*phase_angle
magnitude=np.abs(fshift)
phase_angle=np.angle(fshift)  # a real number

phase_only=fshift/magnitude  #   (magnitude*e^j*phase_angle)/magnitude=e^j*phase_angle

# reconstrtuction of phase_only
phase_only_ishift=np.fft.ifftshift(phase_only)
# taking inverse to get back in image domain (complex)
phase_only_image_complex=np.fft.ifft2(phase_only_ishift)
#interested in real values
phase_only_image=np.abs(phase_only_image_complex)

# reconstruction of phase_angle
phase_angle_ishift=np.fft.ifftshift(phase_angle)
phase_angle_image_complex=np.fft.ifft2(phase_angle_ishift)
phase_angle_image=np.abs(phase_angle_image_complex)

#display images
plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
plt.imshow(gray_scale2,cmap="gray")
plt.title("original image")
plt.axis("off")




plt.subplot(1,3,2)
plt.imshow(phase_only_image,cmap="gray")
plt.title("phase_only_image")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(phase_angle_image,cmap="gray")
plt.title("phase_angle_image")
plt.axis("off")

plt.show()

# phase_only = fshift / np.abs(fshift) gives the e^j*phase_angle complex form which sets all  magnitudes equal to one but still a complex number so it is a valid fourir tranform
# taking inverse of it still preserves the edges and  shapes
#  np.angle(f_shift)  returns the phase angle as real number so if we directly invert  this real number , reconstructed image will lost its shapes and edges

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# using magnitude only reconstruction
mag_only=np.abs(fshift)
mag_only_db=20*np.log10(mag_only)
# applying reconstruction
mag_only_ishift=np.fft.ifftshift(mag_only)    # inverse shifting
mag_only_image_complex=np.fft.ifft2(mag_only_ishift)    # inverse tranform to get back image 2d complex array
mag_only_image=np.abs(mag_only_image_complex)

#display images
plt.figure(figsize=(12,5))
plt.subplot(1,4,1)
plt.imshow(gray_scale2,cmap="gray")
plt.title("original image")
plt.axis("off")

plt.subplot(1,4,2)
plt.imshow(mag_only_image,cmap="gray")
plt.title("mag_only")
plt.axis("off")

plt.subplot(1,4,3)
plt.imshow(phase_only_image,cmap="gray")
plt.title("phase_only")
plt.axis("off")

plt.subplot(1,4,4)
plt.imshow(mag_only_db,cmap="gray")
plt.title("magnitude spectrum")
plt.axis("off")


plt.show()

# here we use log in magnitude spectrum for visualization to reduce a high ranges of frequencies into lower so that they can be easily  visible
# for mag_only reconstruction we have to use a raw magnitudes not a log to achieve a true reconstruction so this is why this is different from magnitude spectrum
#for mag_only phase is zero for all frequencies components and we see all the information is lost and a blurred dark image is apperead
# SO basically phase is considered more important then magnitude where phase preserves the structural information which includes edges and shapes and magnitude affects the intensity

# %% [markdown]
# ## Bonus - Part E
#
# Load another image as you did before. Then swap magnitude and phase between them. In other words, for both images, find the magnitudes and phases. Combine magnitude of image 1 with phase of image 2. Also combine magnitude of 2 with phase of 1. Then reconstruct and display the resultant images.
#
# ![image.png](data:image/png;base64,...)
#
# Do you notice how phase describes structure and magnitude describes texture of image ? Mention at last in code comments.

# %%
# Your PART E codes follow here. You can create more cells under this. Write clean and commented code.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c6bd0ec2-f069-459e-a3c8-eb4f727440d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6bd0ec2-f069-459e-a3c8-eb4f727440d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import base64
with open("WhatsApp Image 2025-06-26 at 18.25.36_f2dcd3bc.jpg", "rb") as img_file:
    print(base64.b64encode(img_file.read()).decode())
# Out:
# ...

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image1 = """...
"""  # long base64 string

img1_data = base64.b64decode(base64_image1)
img1 = Image.open(io.BytesIO(img1_data))

plt.imshow(img1)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(245.5), np.float64(452.5), np.float64(-0.5))

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
#ensuring img1 is in RGB mode
img1_rgb=img1.convert("RGB")
# converting into 3d array of shape(H,W,3)
img1_rgb=np.array(img1_rgb)
# converting to grayscale  2d array of shape(H,W)
gray_scale_original=cv2.cvtColor(img1_rgb,cv2.COLOR_RGB2GRAY)   # 2nd grayscal image
# resizing this so that both img have same sizes
gray_scale=cv2.resize(gray_scale_original,(gray_scale2.shape[1],gray_scale2.shape[0]))  # gray_scale2.shape=[height,width]
# calculating its FFT
f_transform=np.fft.fft2(gray_scale)
#shifting low frequenies to centre
fshift1=np.fft.fftshift(f_transform)   # shifted fourier tranform of 2nd gray scale image

# calculating magnitude and phase for each image
# 1st grayscale image(img)
magnitude1=np.abs(fshift)
phase1=np.angle(fshift)

#2nd grayscale image(img1)
magnitude2=np.abs(fshift1)
phase2=np.angle(fshift1)


# fshift[m,n]=magnitude1[m,n]*e^j*phase1[m,n]
# fshift1[m,n]=magnitude2[m,n]*e^j*phase2[m,n]

# creating new spectra by swapping magnitudes and phase
fshift_swapped=magnitude1*np.exp(1j*phase2)
fshift1_swapped=magnitude2*np.exp(1j*phase1)


# reconstruction of fshift_swapped
fshift_swapped_ishift=np.fft.ifftshift(fshift_swapped)
# taking inverse to get back in image domain of 2d complex array
resultant_img1_complex=np.fft.ifft2(fshift_swapped_ishift)
resultant_img1=np.abs(resultant_img1_complex)   # resutant img 1

# reconstruction of fshift1_swapped
fshift1_swapped_ishift=np.fft.ifftshift(fshift1_swapped)
# taking inverse to get back in image domain of 2d complex array
resultant_img2_complex=np.fft.ifft2(fshift1_swapped_ishift)
resultant_img2=np.abs(resultant_img2_complex)    # resultant img 2


#display images
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.imshow(resultant_img1,cmap="gray")
plt.title("resultant img 1")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(resultant_img2,cmap="gray")
plt.title("resultant img 2")
plt.axis("off")

plt.show()


# Resutant img 1 have  FFT fshift_swapped  where magnitude comes from 1st loaded image and phase comes from 2nd loaded image
# we can see that since resultant img 1 have a phase part from 2nd loaded image ,structural information which includes shapes,edges comes from 2nd loaded image
# and brightness/intensiy comes from 1st loaded image
# Resultant img 2 have  FFT fshift1_swapped where magnitude comes from 2nd loaded image and phase comes from 1st loaded image
# we can see that since resultant img 2 have a phase part from 1st loaded image , structural information which includes shapes and edges comes from 1st loaded image
# and brigthness.intensity comes from 2nd loaded image

# Therefore we can say that Phase contains structral information of image and magnitude controls brightness.intensity
