# %% [markdown]
# # Assignment 1

# %% [markdown]
# ## A bit of info before you start.
#
#
# > ***First and foremost, dont use AI to code. Use it to understand and then write code yourself. Use AI to verify if the code you wrote it correct, that will help you learn far far more.***
#
# > ***Implement Stuff from sratch. Use cv2 functions only when numpy implementation can be extremely tedious.***
#
#
#
# You will need to use your own image for this assignment, which you need to import into here.
# If you cant fetch your image from any APIs that dont need credentials, then :
# To preserve an image in Google Colab without a continuous runtime or using Google Drive, you can use base64 string encoding of images ( its really simple )
#
# First, begin by normally uploading the image into the contents folders as you normally do in colab or fetch it using Drive or any API.
#
# To get the base64 string :
# ```
# import base64
# with open("your_image.jpg", "rb") as img_file:
#     print(base64.b64encode(img_file.read()).decode())
# ```
#
# Note that the base64 string is a very long string, click on the three dot icon to the left of the current code cell and click on <code> Copy Cell Output </code> to easily copy it to your clipboard.
#
# Then, to embed the string into your Jupyter Notebook :
# ```
# from PIL import Image
# import io
# import base64
# import matplotlib.pyplot as plt
# import numpy as np
#
# # PASTE BASE64 STRING HERE
# base64_image = "iVBORw0K..."  # long base64 string
#
# img_data = base64.b64decode(base64_image)
# img = Image.open(io.BytesIO(img_data))
#
# plt.imshow(img)
# plt.axis("off")
# ```
# The string is really long so, use a multiline string in python ( syntax : """ """ )
#
# Otherwise, you can also choose to use any API ( try researching on https://picsum.photos/ )

# %% [markdown]
# ## Part A
#
# ### Load your image
#
# 1. Display it in RGB
#
# 2. Convert to grayscale ( use NumPy to calculate aggregates using the weighted sum formula )
#
# 3. Use the cvtColor function to do the same and compare results
#
# 3. Print the array shapes of both the RGB and grayscale images
#
# 4. Print a few pixel values of both
#
# ( Do you notice the difference that number of channels created on the array shape ?? )

# %%
# Your PART A codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import base64
with open("/content/rahman dakait.webp", "rb") as img_file:
    print(base64.b64encode(img_file.read()).decode())
# Out:
# ...

# %%
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image = """...
"""  # long base64 string

img_data = base64.b64decode(base64_image)
img = Image.open(io.BytesIO(img_data))

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(859.5), np.float64(483.5), np.float64(-0.5))

# %%
import numpy as np
import matplotlib.pyplot as plt
img_rgb=np.array(img)
print(img_rgb.shape)
plt.imshow(img_rgb)
img_gray=img_rgb[:,:,0]*0.3+img_rgb[:,:,1]*0.59+img_rgb[:,:,2]*0.11
print(img_gray.shape)
plt.imshow(img_gray, cmap='gray')
# Out:
# (484, 860, 3)
# (484, 860)

# %%
import cv2
gray=cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)
plt.imshow(gray, cmap='gray')
print(gray.shape, img_rgb.shape)
# Out:
# (484, 860) (484, 860, 3)

# %%
print(gray[:5,:5])
# Out:
# [[41 41 41 40 38]
#  [41 41 41 40 38]
#  [41 41 41 40 38]
#  [40 40 40 38 38]
#  [38 38 38 38 38]]

# %%
print(img_rgb[:5,:5,:])
# Out:
# [[[49 40 25]
#   [49 40 25]
#   [49 40 25]
#   [48 39 23]
#   [46 37 22]]
#
#  [[49 40 25]
#   [49 40 25]
#   [49 40 25]
#   [48 39 23]
#   [46 37 22]]
#
#  [[49 40 25]
#   [49 40 25]
#   [49 40 25]
#   [48 39 23]
#   [46 37 22]]
#
#  [[48 39 23]
#   [48 39 23]
#   [48 39 23]
#   [46 37 22]
#   [46 37 22]]
#
#  [[46 37 22]
#   [46 37 22]
#   [46 37 22]
#   [46 37 22]
#   [47 36 21]]]

# %% [markdown]
# ## Part B
# ### B1. Compute the FFT of the grayscale image ( use NumPy )
# Steps:
# 1. <code>np.fft.fft2</code>
# 2. <code>np.fft.fftshift</code>
# 3. Store as <code>fshift</code>
#
# ### B2. Compute magnitude, phase and display Magnitude Spectrum

# %%
# Your PART B codes follow here. You can create more cells under this. Write clean and commented code.

# %%
gray_float=gray.astype(np.float32)
gray_fft=np.fft.fft2(gray_float)
fshift=np.fft.fftshift(gray_fft)

# %%
magnitude_spectrum = np.abs(fshift)
magnitude_spectrum_log = 20 * np.log(1 + magnitude_spectrum)
phase_spectrum = np.angle(fshift)
plt.figure(figsize=(12, 6))
plt.subplot(121), plt.imshow(magnitude_spectrum_log, cmap='gray')
plt.title('Magnitude Spectrum (Log Scale)'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(phase_spectrum, cmap='gray')
plt.title('Phase Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# Magnitude spectrum (log scaled) and phase spectrum calculated.

# %% [markdown]
# ## Part C
# ### C1. Create 3 LPF masks
#
# Radii of filter: 10, 30, 80 (or image-size dependent, mention if you change)
#
# For each:
#
# 1. Create a mask
#
# 2. Apply to <code>fshift</code>
#
# 3. Reconstruct using <code>ifftshift + ifft2</code>
#
# 4. Show blur levels increasing as radius decreases ( think why and write reason in code comment )
#
# ### C2. Create HPF mask
#
# 1. Apply
#
# 2. Reconstruct
#
# ### C3. Create a square LPF mask
# Keep side of square as 50. The square will be at the center of the filter.
# Apply, Recontruct and show the output.

# %%
# Your PART C codes follow here. You can create more cells under this. Write clean and commented code.

# %%
rows, cols = gray.shape
crow, ccol = rows//2, cols//2
#10
radius1 = 10
mask_lpf = np.zeros((rows, cols), np.uint8)
cv2.circle(mask_lpf, (ccol, crow), radius1, 1, -1)
f_lpf = fshift * mask_lpf
ishift_lpf = np.fft.ifftshift(f_lpf)
img_back_lpf_1 = np.fft.ifft2(ishift_lpf)
img_back_lpf_1 = np.abs(img_back_lpf_1)
#30
radius2 = 30
mask_lpf = np.zeros((rows, cols), np.uint8)
cv2.circle(mask_lpf, (ccol, crow), radius2, 1, -1)
f_lpf = fshift * mask_lpf
ishift_lpf = np.fft.ifftshift(f_lpf)
img_back_lpf_2 = np.fft.ifft2(ishift_lpf)
img_back_lpf_2 = np.abs(img_back_lpf_2)
#80
radius3 = 80
mask_lpf = np.zeros((rows, cols), np.uint8)
cv2.circle(mask_lpf, (ccol, crow), radius3, 1, -1)
f_lpf = fshift * mask_lpf
ishift_lpf = np.fft.ifftshift(f_lpf)
img_back_lpf_3 = np.fft.ifft2(ishift_lpf)
img_back_lpf_3 = np.abs(img_back_lpf_3)

plt.figure(figsize=(12,6))
plt.subplot(1, 3, 1)
plt.imshow(img_back_lpf_1, cmap='gray')
plt.title(f'Low Pass Filter (Radius={radius1})')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(img_back_lpf_2, cmap='gray')
plt.title(f'Low Pass Filter (Radius={radius2})')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(img_back_lpf_3, cmap='gray')
plt.title(f'Low Pass Filter (Radius={radius3})')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(859.5), np.float64(483.5), np.float64(-0.5))

# %%
mask_hpf = 1 - mask_lpf
f_hpf = fshift * mask_hpf
ishift_hpf = np.fft.ifftshift(f_hpf)
img_back_hpf = np.fft.ifft2(ishift_hpf)
img_back_hpf = np.abs(img_back_hpf)
plt.figure(figsize=(6,6))
plt.imshow(img_back_hpf, cmap='gray')
plt.title('High Pass Filter (Edge Detection)')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Part D
#
# ###D1. Phase-only reconstruction
#
# Use: <code>phase_only = fshift / np.abs(fshift)</code>
#
# 1. Reconstruct and display.
# 2. Also in code comments, mention the differnce between this code line and the one in the lecture : <code>np.angle(f_shift)</code>
# 3. Try recontruction from <code>np.angle(f_shift)</code> once and explain your output in code comments.
#
#
#
# ###D2. Magnitude-only reconstruction
#
# Use: <code>mag_only = np.abs(fshift)</code>
#
# 1. Reconstruct and display.
# 2. Take a guess for the role of logarithm in Magnitude Spectrum. Why does this look different than what Magnitude Spectrum looked like ? Mention in code comments again.

# %%
# Your PART D codes follow here. You can create more cells under this. Write clean and commented code.

# %%
phase_only_complex = fshift / np.abs(fshift)
ishift_phase = np.fft.ifftshift(phase_only_complex)
img_phase = np.fft.ifft2(ishift_phase)
img_phase = np.abs(img_phase)
angle_values = np.angle(fshift)
ishift_angle_raw = np.fft.ifftshift(angle_values)
img_angle_raw = np.fft.ifft2(ishift_angle_raw)
img_angle_raw = np.abs(img_angle_raw)

plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.imshow(img_phase, cmap='gray')
plt.title('Reconstruction using Phase Only\n(Structure Preserved)')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(img_angle_raw, cmap='gray')
plt.title('Reconstruction from np.angle()\n(Garbage Output)')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(859.5), np.float64(483.5), np.float64(-0.5))

# %% [markdown]
# Difference between fshift / np.abs(fshift) and np.angle(fshift):
# fshift / np.abs(fshift) returns a COMPLEX number with length 1 (e^jθ).
# This preserves the mathematical format needed for the Inverse FFT.
# np.angle(fshift) returns a simple FLOAT value (the angle θ in radians).
# If we feed this float into ifft2, the computer thinks these angles are actually
# pixel intensity values, not phase info, leading to a garbage result.

# %% [markdown]
# ## Bonus - Part E
#
# Load another image as you did before. Then swap magnitude and phase between them. In other words, for both images, find the magnitudes and phases. Combine magnitude of image 1 with phase of image 2. Also combine magnitude of 2 with phase of 1. Then reconstruct and display the resultant images.
#
# ![image.png](data:image/png;base64,...)
#
# Do you notice how phase describes structure and magnitude describes texture of image ? Mention at last in code comments.

# %%
# Your PART E codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import base64
with open("/content/dhurandhar.webp", "rb") as img_file:
    print(base64.b64encode(img_file.read()).decode())
# Out:
# ...

# %%
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image = """...
"""  # long base64 string

img_data = base64.b64decode(base64_image)
img = Image.open(io.BytesIO(img_data))

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(499.5), np.float64(374.5), np.float64(-0.5))

# %%
img2_rgb = np.array(img)
img2_gray = img2_rgb[:,:,0]*0.3 + img2_rgb[:,:,1]*0.59 + img2_rgb[:,:,2]*0.11
img2_gray_float = img2_gray.astype(np.float32)
img2_fft = np.fft.fft2(img2_gray_float)
img2_fshift = np.fft.fftshift(img2_fft)
magnitude_spectrum_img2 = np.abs(img2_fshift)
phase_spectrum_img2 = np.angle(img2_fshift)

# %%
rows, cols = gray.shape
img = img.resize((cols, rows))

# %%
img2_rgb = np.array(img)
img2_gray = img2_rgb[:,:,0]*0.3 + img2_rgb[:,:,1]*0.59 + img2_rgb[:,:,2]*0.11
img2_gray_float = img2_gray.astype(np.float32)
img2_fft = np.fft.fft2(img2_gray_float)
img2_fshift = np.fft.fftshift(img2_fft)
magnitude_spectrum_img2 = np.abs(img2_fshift)
phase_spectrum_img2 = np.angle(img2_fshift)

# %%
combined_fshift_1_mag_2_phase = magnitude_spectrum * np.exp(1j * phase_spectrum_img2)
ishift_1_mag_2_phase = np.fft.ifftshift(combined_fshift_1_mag_2_phase)
img_1_mag_2_phase = np.fft.ifft2(ishift_1_mag_2_phase)
img_1_mag_2_phase = np.abs(img_1_mag_2_phase)

plt.figure(figsize=(10, 5))
plt.imshow(img_1_mag_2_phase, cmap='gray')
plt.title('Image with Magnitude of Image 1 and Phase of Image 2')
plt.axis('off')
plt.show()

# %%
combined_fshift_2_mag_1_phase = magnitude_spectrum_img2 * np.exp(1j * phase_spectrum)
ishift_2_mag_1_phase = np.fft.ifftshift(combined_fshift_2_mag_1_phase)
img_2_mag_1_phase = np.fft.ifft2(ishift_2_mag_1_phase)
img_2_mag_1_phase = np.abs(img_2_mag_1_phase)

plt.figure(figsize=(10, 5))
plt.imshow(img_2_mag_1_phase, cmap='gray')
plt.title('Image with Magnitude of Image 2 and Phase of Image 1')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Magnitude and Phase Observatipns:
#
# When we combine the magnitude of Image 1 with the phase of Image 2, the reconstructed image (Image with Magnitude of Image 1 and Phase of Image 2) largely resembles Image 2 in terms of its structure and recognizable features, but with the overall brightness and contrast characteristics (texture) of Image 1.
#
# Conversely, when we combine the magnitude of Image 2 with the phase of Image 1, the reconstructed image (Image with Magnitude of Image 2 and Phase of Image 1) predominantly shows the structure and recognizable features of Image 1, but with the texture and intensity variations of Image 2.
#
# This demonstrates that:
# *   Phase information is crucial for preserving the structure, edges, and recognizable features of an image. It dictates where things are in the image.
# *   Magnitude information primarily contributes to the texture, brightness, and contrast of an image. It dictates how intense those features appear.
